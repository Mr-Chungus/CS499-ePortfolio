# %% [markdown]
# # CS-499 Animal Shelter Dashboard – Final Enhanced Artifact
#
# This notebook is now a small launcher instead of containing the whole application in one cell. The implementation is separated into modules for software engineering, includes a configurable rescue suitability ranking algorithm, and retains the enhanced MongoDB CRUD layer.

# %% [markdown]
# ## Before running
# Copy `.env.example` to `.env` and enter the MongoDB settings for the AAC environment. No username or password is stored in this notebook.

# %%
# Import JupyterDash so the modular Dash application can run inside a notebook.
from jupyter_dash import JupyterDash

# Import the application factory instead of placing the full program in this cell.
from app import create_app

# Build the application using JupyterDash while reusing the same modules as app.py.
app = create_app(app_class=JupyterDash)

# Start the dashboard in debug mode for development and troubleshooting.
app.run_server(debug=True)
